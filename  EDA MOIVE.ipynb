# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv("C:/Users/pc/Downloads/movies.csv")

# %%
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0        1705  1705
# 1   327       55   4500000.0   58853106.0      731    104.0        1492  1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0        1771  1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0        1492  1492
# 4   410       55   6000000.0   39846344.0     1777     98.0        1543  1543

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df['yearcorrect'] = df['released'].astype(str).str[:4]

df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0        1705  1705
# 1   327       55   4500000.0   58853106.0      731    104.0        1492  1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0        1771  1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0        1492  1492
# 4   410       55   6000000.0   39846344.0     1777     98.0        1543  1543

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False).head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   533       5      0  2009       696    7.8  1100000.0      1155    1778
# 7445   535       5      0  2019       183    8.4   903000.0       162     743
# 3045  6896       5      6  1997       704    7.8  1100000.0      1155    1778
# 6663  5144       5      0  2015       698    7.8   876000.0      1125    2550
# 7244   536       5      0  2018       192    8.4   897000.0       162     743
#
#       star  country       budget         gross  company  runtime  yearcorrect  \
# 5445  2334       55  237000000.0  2.847246e+09     2253    162.0         3078
# 7445  2241       55  356000000.0  2.797501e+09     1606    181.0          925
# 3045  1595       55  200000000.0  2.201647e+09     2253    194.0         3088
# 6663   524       55  245000000.0  2.069522e+09     1540    138.0         3080
# 7244  2241       55  321000000.0  2.048360e+09     1606    149.0         1025
#
#      Year
# 5445  696
# 7445  183
# 3045  704
# 6663  698
# 7244  192

# %%
#pd.set_option('display.max_rows',None)

# %%
df.boxplot(column=['gross'])
# Out:
# <Axes: >

# %%
df.drop_duplicates().head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0        1705  1705
# 1   327       55   4500000.0   58853106.0      731    104.0        1492  1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0        1771  1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0        1492  1492
# 4   410       55   6000000.0   39846344.0     1777     98.0        1543  1543

# %%
sns.regplot(x='budget',y='gross',data=df,scatter_kws={"color": "red"},line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr().head()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\2670547417.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().head()
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
#
#              votes  director    writer      star   country    budget  \
# name      0.013088  0.009079  0.009081  0.006472 -0.010737  0.023970
# rating    0.033225  0.019483 -0.005921  0.013405  0.081244 -0.176002
# genre    -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.356564
# year      0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.329321
# released  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.014683
#
#              gross   company   runtime
# name      0.005533  0.009211  0.010392
# rating   -0.107339 -0.032943  0.062145
# genre    -0.235650 -0.071067 -0.052711
# year      0.257486 -0.010431  0.120811
# released  0.001659 -0.010474  0.000868

# %%
df.corr(method='pearson') #pearson , kendall, spearman
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\228108072.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson') #pearson , kendall, spearman
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score     0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes     0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director  0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer    0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star      0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country  -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget    0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# gross     0.005533 -0.107339 -0.235650  0.257486  0.001659  0.186258
# company   0.009211 -0.032943 -0.071067 -0.010431 -0.010474  0.001030
# runtime   0.010392  0.062145 -0.052711  0.120811  0.000868  0.399451
#
#              votes  director    writer      star   country    budget  \
# name      0.013088  0.009079  0.009081  0.006472 -0.010737  0.023970
# rating    0.033225  0.019483 -0.005921  0.013405  0.081244 -0.176002
# genre    -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.356564
# year      0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.329321
# released  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.014683
# score     0.409182  0.009559  0.019416 -0.001609 -0.133348  0.076254
# votes     1.000000  0.000260  0.000892 -0.019282  0.073625  0.442429
# director  0.000260  1.000000  0.299067  0.039234  0.017490 -0.012272
# writer    0.000892  0.299067  1.000000  0.027245  0.015343 -0.039451
# star     -0.019282  0.039234  0.027245  1.000000 -0.012998 -0.019589
# country   0.073625  0.017490  0.015343 -0.012998  1.000000  0.054063
# budget    0.442429 -0.012272 -0.039451 -0.019589  0.054063  1.000000
# gross     0.630757 -0.014441 -0.023519 -0.002717  0.092129  0.740395
# company   0.133204  0.004404  0.005646  0.012442  0.095548  0.173214
# runtime   0.309212  0.017624 -0.003511  0.010174 -0.078412  0.320447
#
#              gross   company   runtime
# name      0.005533  0.009211  0.010392
# rating   -0.107339 -0.032943  0.062145
# genre    -0.235650 -0.071067 -0.052711
# year      0.257486 -0.010431  0.120811
# released  0.001659 -0.010474  0.000868
# score     0.186258  0.001030  0.399451
# votes     0.630757  0.133204  0.309212
# director -0.014441  0.004404  0.017624
# writer   -0.023519  0.005646 -0.003511
# star     -0.002717  0.012442  0.010174
# country   0.092129  0.095548 -0.078412
# budget    0.740395  0.173214  0.320447
# gross     1.000000  0.154840  0.245216
# company   0.154840  1.000000  0.034402
# runtime   0.245216  0.034402  1.000000

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('correlation matrix for numeric features')

plt.xlabel('Movie features')

plt.ylabel('Movie features')


plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_14516\2428029037.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr(method='pearson')

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0          787   787
# 1   327       55   4500000.0   58853106.0      731    104.0          550   550
# 2  1745       55  18000000.0  538375067.0     1540    124.0          860   860
# 3  2246       55   3500000.0   83453539.0     1812     88.0          550   550
# 4   410       55   6000000.0   39846344.0     1777     98.0          607   607

# %%
correlation_matrix = df_numerized.corr(method='pearson')

sns.heatmap(correlation_matrix, annot=True)

plt.title('correlation matrix for numeric features')

plt.xlabel('Movie features')

plt.ylabel('Movie features')


plt.show()

# %%
df_numerized.corr().head()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating   -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre     0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year      0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
#
#              votes  director    writer      star   country    budget  \
# name      0.013088  0.009079  0.009081  0.006472 -0.010737  0.023970
# rating    0.033225  0.019483 -0.005921  0.013405  0.081244 -0.176002
# genre    -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.356564
# year      0.222945 -0.020795 -0.008656 -0.027242 -0.070938  0.329321
# released  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.014683
#
#              gross   company   runtime  yearcorrect      Year
# name      0.005533  0.009211  0.010392     0.002843  0.002843
# rating   -0.107339 -0.032943  0.062145    -0.011441 -0.011441
# genre    -0.235650 -0.071067 -0.052711     0.018393  0.018393
# year      0.257486 -0.010431  0.120811    -0.010495 -0.010495
# released  0.001659 -0.010474  0.000868     0.001014  0.001014

# %%
correlation_mat = df_numerized.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.008069
#              genre          0.016355
#              year           0.011453
#              released      -0.011311
#              score          0.017097
#              votes          0.013088
#              director       0.009079
#              writer         0.009081
#              star           0.006472
#              country       -0.010737
#              budget         0.023970
#              gross          0.005533
#              company        0.009211
#              runtime        0.010392
#              yearcorrect    0.002843
#              Year           0.002843
# rating       name          -0.008069
#              rating         1.000000
#              genre          0.072423
#              year           0.008779
#              released       0.016613
#              score         -0.001314
#              votes          0.033225
#              director       0.019483
#              writer        -0.005921
#              star           0.013405
#              country        0.081244
#              budget        -0.176002
#              gross         -0.107339
#              company       -0.032943
#              runtime        0.062145
#              yearcorrect   -0.011441
#              Year          -0.011441
# genre        name           0.016355
#              rating         0.072423
#              genre          1.000000
#              year          -0.081261
#              released       0.029822
#              score          0.027965
#              votes         -0.145307
#              director      -0.015258
#              writer         0.006567
#              star          -0.005477
#              country       -0.037615
#              budget        -0.356564
#              gross         -0.235650
#              company       -0.071067
#              runtime       -0.052711
#              yearcorrect    0.018393
#              Year           0.018393
# year         name           0.011453
#              rating         0.008779
#              genre         -0.081261
#              year           1.000000
#              released      -0.000695
#              score          0.097995
#              votes          0.222945
#              director      -0.020795
#              writer        -0.008656
#              star          -0.027242
#              country       -0.070938
#              budget         0.329321
#              gross          0.257486
#              company       -0.010431
#              runtime        0.120811
#              yearcorrect   -0.010495
#              Year          -0.010495
# released     name          -0.011311
#              rating         0.016613
#              genre          0.029822
#              year          -0.000695
#              released       1.000000
#              score          0.042788
#              votes          0.016097
#              director      -0.001478
#              writer        -0.002404
#              star           0.015777
#              country       -0.020427
#              budget         0.014683
#              gross          0.001659
#              company       -0.010474
#              runtime        0.000868
#              yearcorrect    0.001014
#              Year           0.001014
# score        name           0.017097
#              rating        -0.001314
#              genre          0.027965
#              year           0.097995
#              released       0.042788
#              score          1.000000
#              votes          0.409182
#              director       0.009559
#              writer         0.019416
#              star          -0.001609
#              country       -0.133348
#              budget         0.076254
#              gross          0.186258
#              company        0.001030
#              runtime        0.399451
#              yearcorrect    0.023247
#              Year           0.023247
# votes        name           0.013088
#              rating         0.033225
#              genre         -0.145307
#              year           0.222945
#              released       0.016097
#              score          0.409182
#              votes          1.000000
#              director       0.000260
#              writer         0.000892
#              star          -0.019282
#              country        0.073625
#              budget         0.442429
#              gross          0.630757
#              company        0.133204
#              runtime        0.309212
#              yearcorrect   -0.009806
#              Year          -0.009806
# director     name           0.009079
#              rating         0.019483
#              genre         -0.015258
#              year          -0.020795
#              released      -0.001478
#              score          0.009559
#              votes          0.000260
#              director       1.000000
#              writer         0.299067
#              star           0.039234
#              country        0.017490
#              budget        -0.012272
#              gross         -0.014441
#              company        0.004404
#              runtime        0.017624
#              yearcorrect   -0.014800
#              Year          -0.014800
# writer       name           0.009081
#              rating        -0.005921
#              genre          0.006567
#              year          -0.008656
#              released      -0.002404
#              score          0.019416
#              votes          0.000892
#              director       0.299067
#              writer         1.000000
#              star           0.027245
#              country        0.015343
#              budget        -0.039451
#              gross         -0.023519
#              company        0.005646
#              runtime       -0.003511
#              yearcorrect    0.001402
#              Year           0.001402
# star         name           0.006472
#              rating         0.013405
#              genre         -0.005477
#              year          -0.027242
#              released       0.015777
#              score         -0.001609
#              votes         -0.019282
#              director       0.039234
#              writer         0.027245
#              star           1.000000
#              country       -0.012998
#              budget        -0.019589
#              gross         -0.002717
#              company        0.012442
#              runtime        0.010174
#              yearcorrect    0.004909
#              Year           0.004909
# country      name          -0.010737
#              rating         0.081244
#              genre         -0.037615
#              year          -0.070938
#              released      -0.020427
#              score         -0.133348
#              votes          0.073625
#              director       0.017490
#              writer         0.015343
#              star          -0.012998
#              country        1.000000
#              budget         0.054063
#              gross          0.092129
#              company        0.095548
#              runtime       -0.078412
#              yearcorrect   -0.011358
#              Year          -0.011358
# budget       name           0.023970
#              rating        -0.176002
#              genre         -0.356564
#              year           0.329321
#              released       0.014683
#              score          0.076254
#              votes          0.442429
#              director      -0.012272
#              writer        -0.039451
#              star          -0.019589
#              country        0.054063
#              budget         1.000000
#              gross          0.740395
#              company        0.173214
#              runtime        0.320447
#              yearcorrect   -0.020078
#              Year          -0.020078
# gross        name           0.005533
#              rating        -0.107339
#              genre         -0.235650
#              year           0.257486
#              released       0.001659
#              score          0.186258
#              votes          0.630757
#              director      -0.014441
#              writer        -0.023519
#              star          -0.002717
#              country        0.092129
#              budget         0.740395
#              gross          1.000000
#              company        0.154840
#              runtime        0.245216
#              yearcorrect   -0.024954
#              Year          -0.024954
# company      name           0.009211
#              rating        -0.032943
#              genre         -0.071067
#              year          -0.010431
#              released      -0.010474
#              score          0.001030
#              votes          0.133204
#              director       0.004404
#              writer         0.005646
#              star           0.012442
#              country        0.095548
#              budget         0.173214
#              gross          0.154840
#              company        1.000000
#              runtime        0.034402
#              yearcorrect   -0.023268
#              Year          -0.023268
# runtime      name           0.010392
#              rating         0.062145
#              genre         -0.052711
#              year           0.120811
#              released       0.000868
#              score          0.399451
#              votes          0.309212
#              director       0.017624
#              writer        -0.003511
#              star           0.010174
#              country       -0.078412
#              budget         0.320447
#              gross          0.245216
#              company        0.034402
#              runtime        1.000000
#              yearcorrect    0.021713
#              Year           0.021713
# yearcorrect  name           0.002843
#              rating        -0.011441
#              genre          0.018393
#              year          -0.010495
#              released       0.001014
#              score          0.023247
#              votes         -0.009806
#              director      -0.014800
#              writer         0.001402
#              star           0.004909
#              country       -0.011358
#              budget        -0.020078
#              gross         -0.024954
#              company       -0.023268
#              runtime        0.021713
#              yearcorrect    1.000000
#              Year           1.000000
# Year         name           0.002843
#              rating        -0.011441
#              genre          0.018393
#              year          -0.010495
#              released       0.001014
#              score          0.023247
#              votes         -0.009806
#              director      -0.014800
#              writer         0.001402
#              star           0.004909
#              country       -0.011358
#              budget        -0.020078
#              gross         -0.024954
#              company       -0.023268
#              runtime        0.021713
#              yearcorrect    1.000000
#              Year           1.000000
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs.head()
# Out:
# budget  genre    -0.356564
# genre   budget   -0.356564
#         gross    -0.235650
# gross   genre    -0.235650
# budget  rating   -0.176002
# dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# budget       genre         -0.356564
# genre        budget        -0.356564
#              gross         -0.235650
# gross        genre         -0.235650
# budget       rating        -0.176002
# rating       budget        -0.176002
# genre        votes         -0.145307
# votes        genre         -0.145307
# score        country       -0.133348
# country      score         -0.133348
# rating       gross         -0.107339
# gross        rating        -0.107339
# year         genre         -0.081261
# genre        year          -0.081261
# country      runtime       -0.078412
# runtime      country       -0.078412
# genre        company       -0.071067
# company      genre         -0.071067
# year         country       -0.070938
# country      year          -0.070938
# runtime      genre         -0.052711
# genre        runtime       -0.052711
# writer       budget        -0.039451
# budget       writer        -0.039451
# country      genre         -0.037615
# genre        country       -0.037615
# rating       company       -0.032943
# company      rating        -0.032943
# star         year          -0.027242
# year         star          -0.027242
# gross        Year          -0.024954
# Year         gross         -0.024954
# yearcorrect  gross         -0.024954
# gross        yearcorrect   -0.024954
# writer       gross         -0.023519
# gross        writer        -0.023519
# yearcorrect  company       -0.023268
# company      yearcorrect   -0.023268
# Year         company       -0.023268
# company      Year          -0.023268
# director     year          -0.020795
# year         director      -0.020795
# country      released      -0.020427
# released     country       -0.020427
# budget       Year          -0.020078
#              yearcorrect   -0.020078
# Year         budget        -0.020078
# yearcorrect  budget        -0.020078
# star         budget        -0.019589
# budget       star          -0.019589
# star         votes         -0.019282
# votes        star          -0.019282
# genre        director      -0.015258
# director     genre         -0.015258
#              yearcorrect   -0.014800
# Year         director      -0.014800
# yearcorrect  director      -0.014800
# director     Year          -0.014800
# gross        director      -0.014441
# director     gross         -0.014441
# star         country       -0.012998
# country      star          -0.012998
# budget       director      -0.012272
# director     budget        -0.012272
# Year         rating        -0.011441
# yearcorrect  rating        -0.011441
# rating       yearcorrect   -0.011441
#              Year          -0.011441
# Year         country       -0.011358
# yearcorrect  country       -0.011358
# country      yearcorrect   -0.011358
#              Year          -0.011358
# name         released      -0.011311
# released     name          -0.011311
# country      name          -0.010737
# name         country       -0.010737
# Year         year          -0.010495
# yearcorrect  year          -0.010495
# year         Year          -0.010495
#              yearcorrect   -0.010495
# company      released      -0.010474
# released     company       -0.010474
# company      year          -0.010431
# year         company       -0.010431
# votes        yearcorrect   -0.009806
#              Year          -0.009806
# Year         votes         -0.009806
# yearcorrect  votes         -0.009806
# writer       year          -0.008656
# year         writer        -0.008656
# name         rating        -0.008069
# rating       name          -0.008069
#              writer        -0.005921
# writer       rating        -0.005921
# genre        star          -0.005477
# star         genre         -0.005477
# runtime      writer        -0.003511
# writer       runtime       -0.003511
# gross        star          -0.002717
# star         gross         -0.002717
# released     writer        -0.002404
# writer       released      -0.002404
# star         score         -0.001609
# score        star          -0.001609
# director     released      -0.001478
# released     director      -0.001478
# rating       score         -0.001314
# score        rating        -0.001314
# year         released      -0.000695
# released     year          -0.000695
# votes        director       0.000260
# director     votes          0.000260
# released     runtime        0.000868
# runtime      released       0.000868
# votes        writer         0.000892
# writer       votes          0.000892
# released     yearcorrect    0.001014
# yearcorrect  released       0.001014
# Year         released       0.001014
# released     Year           0.001014
# company      score          0.001030
# score        company        0.001030
# writer       yearcorrect    0.001402
#              Year           0.001402
# Year         writer         0.001402
# yearcorrect  writer         0.001402
# gross        released       0.001659
# released     gross          0.001659
# yearcorrect  name           0.002843
# Year         name           0.002843
# name         Year           0.002843
#              yearcorrect    0.002843
# director     company        0.004404
# company      director       0.004404
# star         yearcorrect    0.004909
#              Year           0.004909
# Year         star           0.004909
# yearcorrect  star           0.004909
# name         gross          0.005533
# gross        name           0.005533
# company      writer         0.005646
# writer       company        0.005646
# name         star           0.006472
# star         name           0.006472
# genre        writer         0.006567
# writer       genre          0.006567
# rating       year           0.008779
# year         rating         0.008779
# director     name           0.009079
# name         director       0.009079
# writer       name           0.009081
# name         writer         0.009081
#              company        0.009211
# company      name           0.009211
# score        director       0.009559
# director     score          0.009559
# runtime      star           0.010174
# star         runtime        0.010174
# runtime      name           0.010392
# name         runtime        0.010392
# year         name           0.011453
# name         year           0.011453
# company      star           0.012442
# star         company        0.012442
# votes        name           0.013088
# name         votes          0.013088
# star         rating         0.013405
# rating       star           0.013405
# budget       released       0.014683
# released     budget         0.014683
# country      writer         0.015343
# writer       country        0.015343
# star         released       0.015777
# released     star           0.015777
# votes        released       0.016097
# released     votes          0.016097
# name         genre          0.016355
# genre        name           0.016355
# released     rating         0.016613
# rating       released       0.016613
# name         score          0.017097
# score        name           0.017097
# country      director       0.017490
# director     country        0.017490
#              runtime        0.017624
# runtime      director       0.017624
# yearcorrect  genre          0.018393
# genre        Year           0.018393
# Year         genre          0.018393
# genre        yearcorrect    0.018393
# score        writer         0.019416
# writer       score          0.019416
# director     rating         0.019483
# rating       director       0.019483
# yearcorrect  runtime        0.021713
# Year         runtime        0.021713
# runtime      yearcorrect    0.021713
#              Year           0.021713
# score        yearcorrect    0.023247
# Year         score          0.023247
# yearcorrect  score          0.023247
# score        Year           0.023247
# budget       name           0.023970
# name         budget         0.023970
# writer       star           0.027245
# star         writer         0.027245
# score        genre          0.027965
# genre        score          0.027965
# released     genre          0.029822
# genre        released       0.029822
# rating       votes          0.033225
# votes        rating         0.033225
# runtime      company        0.034402
# company      runtime        0.034402
# director     star           0.039234
# star         director       0.039234
# released     score          0.042788
# score        released       0.042788
# budget       country        0.054063
# country      budget         0.054063
# runtime      rating         0.062145
# rating       runtime        0.062145
# genre        rating         0.072423
# rating       genre          0.072423
# country      votes          0.073625
# votes        country        0.073625
# budget       score          0.076254
# score        budget         0.076254
# rating       country        0.081244
# country      rating         0.081244
#              gross          0.092129
# gross        country        0.092129
# country      company        0.095548
# company      country        0.095548
# year         score          0.097995
# score        year           0.097995
# year         runtime        0.120811
# runtime      year           0.120811
# company      votes          0.133204
# votes        company        0.133204
# gross        company        0.154840
# company      gross          0.154840
# budget       company        0.173214
# company      budget         0.173214
# score        gross          0.186258
# gross        score          0.186258
# votes        year           0.222945
# year         votes          0.222945
# gross        runtime        0.245216
# runtime      gross          0.245216
# year         gross          0.257486
# gross        year           0.257486
# writer       director       0.299067
# director     writer         0.299067
# votes        runtime        0.309212
# runtime      votes          0.309212
# budget       runtime        0.320447
# runtime      budget         0.320447
# year         budget         0.329321
# budget       year           0.329321
# score        runtime        0.399451
# runtime      score          0.399451
# votes        score          0.409182
# score        votes          0.409182
# budget       votes          0.442429
# votes        budget         0.442429
#              gross          0.630757
# gross        votes          0.630757
# budget       gross          0.740395
# gross        budget         0.740395
# name         name           1.000000
# writer       writer         1.000000
# yearcorrect  yearcorrect    1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# votes        votes          1.000000
# yearcorrect  Year           1.000000
# director     director       1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# company      company        1.000000
# runtime      runtime        1.000000
# Year         yearcorrect    1.000000
#              Year           1.000000
# dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]

high_corr
# Out:
# votes        gross          0.630757
# gross        votes          0.630757
# budget       gross          0.740395
# gross        budget         0.740395
# name         name           1.000000
# writer       writer         1.000000
# yearcorrect  yearcorrect    1.000000
# rating       rating         1.000000
# genre        genre          1.000000
# year         year           1.000000
# released     released       1.000000
# score        score          1.000000
# votes        votes          1.000000
# yearcorrect  Year           1.000000
# director     director       1.000000
# star         star           1.000000
# country      country        1.000000
# budget       budget         1.000000
# gross        gross          1.000000
# company      company        1.000000
# runtime      runtime        1.000000
# Year         yearcorrect    1.000000
#              Year           1.000000
# dtype: float64

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# 2319    56491421806
# 2281    52514188890
# 731     43008941346
# 1812    40493607415
# 2253    40257053857
# 2316    36327887792
# 1713    19883797684
# 1606    15065592411
# 887     11873612858
# 2232    11795832638
# 889     11635441081
# 1637     9230230105
# 2147     8373718838
# 1856     7886344526
# 1109     7443502667
# Name: gross, dtype: int64

# %%
df.groupby(['company', 'year'])[["gross"]].sum().head()
# Out:
#                   gross
# company year
# -1      1983  5563663.0
#         1984  2687148.0
#         1986  3102082.0
#         1989  6693304.0
#         1990  1510053.0

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company  year
# 2316     2019    5773131804
# 1606     2018    4018631866
# 2281     2015    3834354888
# 2253     2009    3793491246
# 2316     2017    3789382071
# 1812     2011    3565705182
# 2319     2010    3300479986
#          2011    3223799224
# 2316     2010    3104474158
# 1812     2014    3071298586
# 731      2006    2934631933
#          2019    2932757449
# 1606     2019    2797501328
# 2319     2018    2774168962
# 731      2011    2738363306
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.groupby(['company', 'year'])[["gross"]].sum().head()
# Out:
#                   gross
# company year
# -1      1983  5563663.0
#         1984  2687148.0
#         1986  3102082.0
#         1989  6693304.0
#         1990  1510053.0

# %%
df['Year'] = df['released'].astype(str).str[:4]
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  yearcorrect  Year
# 0  1047       54  19000000.0   46998772.0     2319    146.0          787  1705
# 1   327       55   4500000.0   58853106.0      731    104.0          550  1492
# 2  1745       55  18000000.0  538375067.0     1540    124.0          860  1771
# 3  2246       55   3500000.0   83453539.0     1812     88.0          550  1492
# 4   410       55   6000000.0   39846344.0     1777     98.0          607  1543
